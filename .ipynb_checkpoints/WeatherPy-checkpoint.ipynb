# %% [markdown]
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **prove** it?
#
# ![Equator](equatorsign.png)
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number, city name, and requested URL.
# * Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must use the Matplotlib and Seaborn libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * You must include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.
#
# ## Hints and Considerations
#
# * You may want to start this assignment by refreshing yourself on 4th grade geography, in particular, the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * Though we've never worked with the [citipy Python library](https://pypi.python.org/pypi/citipy), push yourself to decipher how it works, and why it might be relevant. Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!
#
# * Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?
#
# * In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %% [markdown]
# ## Randomly select at least 1000 unique (non-repeat) cities based on latitude and longitude. And perform a weather check on each of the cities using a series of successive API calls
#
# First we'll create a empty set to hold our city names, python sets do not accept duplicate datapoints which means we don't have to check for duplicates later. longitude ranges from -180 to 180 while latitude ranges from -90 to 90. We use the **random** library's **uniform** function to randomly pick pairings of lat and long values to put into the **citipy** function. The outputed *city names* and *country codes* will be inserted into the *set*. These same city name, country code pairs are sent to the OpenWeatherMaps API and if a city's weather report is found, (https status code 200) it'll be stored in the weather list.  We'll put this all under a **while** loop to keep on generating coordinates and cities until we fill up our weather list with 1000 unique values.

# %%
from citipy import citipy
from random import uniform # Draw samples from a uniform distribution
import requests
from pprint import pprint
from config import key
url = 'http://api.openweathermap.org/data/2.5/weather?'
cities = set()
weather = list()
duplicate_cities = list()
weatherless_cities = set()
while len(weather) < 1001:
    # generate a 1000 unique latitude and longitude values
    
    long = round(uniform(-180,180), 3) #longitude ranges from -180 to 180
    lat = round(uniform(-90, 90), 3) #latitude ranges from -90 to 90
    #feed into citipy the lat, long coordinates to return as city object
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code
    
    # add the city and it's country code to the cities set
    city_entry = f"{city_name},{country_code}"
    if city_entry not in cities:
        cities.add(city_entry)
        print(f"city generated: {city_entry}")
        payload = url + f"{city}"
        keyed_payload = url + "appid=" + key + "&q=" + city_entry + "?"
        print(f"processing request for {payload}")

        response = requests.get(keyed_payload)
        weather_json = response.json()
        print("associated weather data: \n")
        pprint(weather_json)
        if weather_json['cod'] == 200:
            weather.append(weather_json)
        elif weather_json['cod'] == 404:
            weatherless_cities.add(city_entry)
        else:
            pass
    else:
        print(f"duplicate city: {city_entry}")
        duplicate_cities.append(city_entry)
# Out:
# city generated: vila franca do campo,pt
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2E4A860>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: teguldet,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3233CF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 57.31, 'lon': 88.17},
#  'dt': 1520222098,
#  'id': 1489822,
#  'main': {'grnd_level': 1018.62,
#           'humidity': 72,
#           'pressure': 1018.62,
#           'sea_level': 1041.77,
#           'temp': 255.85,
#           'temp_max': 255.85,
#           'temp_min': 255.85},
#  'name': 'Teguldet',
#  'sys': {'country': 'RU',
#          'message': 0.0036,
#          'sunrise': 1520211048,
#          'sunset': 1520250477},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 103.002, 'speed': 2.62}}
# city generated: hermanus,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB383EF98>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1520221799,
#  'id': 3366880,
#  'main': {'grnd_level': 987.09,
#           'humidity': 94,
#           'pressure': 987.09,
#           'sea_level': 1026.41,
#           'temp': 288.125,
#           'temp_max': 288.125,
#           'temp_min': 288.125},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'message': 0.0044,
#          'sunrise': 1520224434,
#          'sunset': 1520270070},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 104.002, 'speed': 1.87}}
# city generated: maloy,no
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2AD94E0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 1, 'lon': 118.1},
#  'dt': 1520222099,
#  'id': 1628757,
#  'main': {'grnd_level': 1008.65,
#           'humidity': 97,
#           'pressure': 1008.65,
#           'sea_level': 1023.86,
#           'temp': 300.075,
#           'temp_max': 300.075,
#           'temp_min': 300.075},
#  'name': 'Maloy',
#  'rain': {'3h': 3.2025},
#  'sys': {'country': 'ID',
#          'message': 0.0036,
#          'sunrise': 1520201775,
#          'sunset': 1520245319},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 9.50192, 'speed': 1.32}}
# city generated: dikson,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB308A780>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: castro,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1DA2400>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -42.48, 'lon': -73.76},
#  'dt': 1520222031,
#  'id': 3896218,
#  'main': {'grnd_level': 1022.92,
#           'humidity': 98,
#           'pressure': 1022.92,
#           'sea_level': 1037.64,
#           'temp': 281.175,
#           'temp_max': 281.175,
#           'temp_min': 281.175},
#  'name': 'Castro',
#  'sys': {'country': 'CL',
#          'message': 0.0046,
#          'sunrise': 1520246407,
#          'sunset': 1520292717},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 279.502, 'speed': 1.27}}
# city generated: albany,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0AFB780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1520220540,
#  'id': 5106834,
#  'main': {'humidity': 74,
#           'pressure': 1019,
#           'temp': 271.64,
#           'temp_max': 273.15,
#           'temp_min': 271.15},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 2898,
#          'message': 0.0048,
#          'sunrise': 1520249026,
#          'sunset': 1520290182,
#          'type': 1},
#  'visibility': 11265,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 280, 'speed': 3.1}}
# city generated: busselton,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0AFDCF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1520222060,
#  'id': 2075265,
#  'main': {'grnd_level': 1028.59,
#           'humidity': 74,
#           'pressure': 1028.59,
#           'sea_level': 1029.7,
#           'temp': 298.9,
#           'temp_max': 298.9,
#           'temp_min': 298.9},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'message': 0.0041,
#          'sunrise': 1520201385,
#          'sunset': 1520246994},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 66.0019, 'speed': 6.47}}
# city generated: severo-kurilsk,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB31EEF60>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: ardistan,ir
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB25F0E48>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: aklavik,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0D18B70>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 68.22, 'lon': -135.01},
#  'dt': 1520218800,
#  'id': 5882953,
#  'main': {'humidity': 85,
#           'pressure': 1030,
#           'temp': 262.15,
#           'temp_max': 262.15,
#           'temp_min': 262.15},
#  'name': 'Aklavik',
#  'sys': {'country': 'CA',
#          'id': 3535,
#          'message': 0.0045,
#          'sunrise': 1520265686,
#          'sunset': 1520302985,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 4.1}}
# city generated: vao,nc
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2A62B00>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 59.1, 'lon': 26.19},
#  'dt': 1520222102,
#  'id': 588365,
#  'main': {'grnd_level': 1016.43,
#           'humidity': 86,
#           'pressure': 1016.43,
#           'sea_level': 1024.95,
#           'temp': 261.325,
#           'temp_max': 261.325,
#           'temp_min': 261.325},
#  'name': 'Vao',
#  'sys': {'country': 'EE',
#          'message': 0.0036,
#          'sunrise': 1520226041,
#          'sunset': 1520265234},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 67.0019, 'speed': 2.07}}
# city generated: yokadouma,cm
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1DBA780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 3.52, 'lon': 15.05},
#  'dt': 1520222103,
#  'id': 2220853,
#  'main': {'grnd_level': 956.29,
#           'humidity': 91,
#           'pressure': 956.29,
#           'sea_level': 1022.8,
#           'temp': 293.325,
#           'temp_max': 293.325,
#           'temp_min': 293.325},
#  'name': 'Yokadouma',
#  'sys': {'country': 'CM',
#          'message': 0.003,
#          'sunrise': 1520226566,
#          'sunset': 1520269986},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 215.502, 'speed': 1.62}}
# city generated: rikitea,pf
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2B5EA58>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: verkhoyansk,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB326C780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 67.55, 'lon': 133.39},
#  'dt': 1520222104,
#  'id': 2013465,
#  'main': {'grnd_level': 984.82,
#           'humidity': 60,
#           'pressure': 984.82,
#           'sea_level': 1032.33,
#           'temp': 247.825,
#           'temp_max': 247.825,
#           'temp_min': 247.825},
#  'name': 'Verkhoyansk',
#  'sys': {'country': 'RU',
#          'message': 0.0029,
#          'sunrise': 1520201350,
#          'sunset': 1520238505},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 335.502, 'speed': 1.72}}
# city generated: meulaboh,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB23EF2B0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: belaya gora,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3054048>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 68.54, 'lon': 146.19},
#  'dt': 1520222105,
#  'id': 2126785,
#  'main': {'grnd_level': 1027.86,
#           'humidity': 63,
#           'pressure': 1027.86,
#           'sea_level': 1035.57,
#           'temp': 247.85,
#           'temp_max': 247.85,
#           'temp_min': 247.85},
#  'name': 'Belaya Gora',
#  'sys': {'country': 'RU',
#          'message': 0.0037,
#          'sunrise': 1520198450,
#          'sunset': 1520235267},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 26.0019, 'speed': 1.67}}
# city generated: faanui,pf
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2B5B7B8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: mataura,pf
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2B5E128>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1520222032,
#  'id': 6201424,
#  'main': {'grnd_level': 1008.89,
#           'humidity': 88,
#           'pressure': 1008.89,
#           'sea_level': 1023.78,
#           'temp': 291.075,
#           'temp_max': 291.075,
#           'temp_min': 291.075},
#  'name': 'Mataura',
#  'rain': {'3h': 0.12},
#  'sys': {'country': 'NZ',
#          'message': 0.0031,
#          'sunrise': 1520187921,
#          'sunset': 1520234758},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 219.002, 'speed': 3.12}}
# city generated: carnarvon,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0B00160>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.97, 'lon': 22.13},
#  'dt': 1520222081,
#  'id': 1014034,
#  'main': {'grnd_level': 873.36,
#           'humidity': 59,
#           'pressure': 873.36,
#           'sea_level': 1025.48,
#           'temp': 284.475,
#           'temp_max': 284.475,
#           'temp_min': 284.475},
#  'name': 'Carnarvon',
#  'sys': {'country': 'ZA',
#          'message': 0.0028,
#          'sunrise': 1520223873,
#          'sunset': 1520269249},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 127.502, 'speed': 1.67}}
# city generated: ribeira grande,pt
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2E3D1D0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: fairbanks,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB34491D0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 64.84, 'lon': -147.72},
#  'dt': 1520220480,
#  'id': 5861897,
#  'main': {'humidity': 85,
#           'pressure': 1031,
#           'temp': 264.48,
#           'temp_max': 266.15,
#           'temp_min': 263.15},
#  'name': 'Fairbanks',
#  'sys': {'country': 'US',
#          'id': 63,
#          'message': 0.0046,
#          'sunrise': 1520268264,
#          'sunset': 1520306493,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 2.1}}
# city generated: kailua,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB34E7F60>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 21.39, 'lon': -157.74},
#  'dt': 1520218620,
#  'id': 5847486,
#  'main': {'humidity': 73,
#           'pressure': 1015,
#           'temp': 297.82,
#           'temp_max': 299.15,
#           'temp_min': 297.15},
#  'name': 'Kailua',
#  'sys': {'country': 'US',
#          'id': 828,
#          'message': 0.0036,
#          'sunrise': 1520268475,
#          'sunset': 1520311019,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 4.6}}
# city generated: geraldton,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0B04160>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 49.72, 'lon': -86.95},
#  'dt': 1520218800,
#  'id': 5960603,
#  'main': {'humidity': 56,
#           'pressure': 1034,
#           'temp': 264.15,
#           'temp_max': 264.15,
#           'temp_min': 264.15},
#  'name': 'Geraldton',
#  'sys': {'country': 'CA',
#          'id': 3656,
#          'message': 0.004,
#          'sunrise': 1520252521,
#          'sunset': 1520293033,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70, 'speed': 4.1}}
# city generated: neiafu,to
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB335A0F0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: xuddur,so
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB32FEC88>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: arraial do cabo,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0BE95C0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1520222051,
#  'id': 3471451,
#  'main': {'grnd_level': 1021.78,
#           'humidity': 98,
#           'pressure': 1021.78,
#           'sea_level': 1022.8,
#           'temp': 298.375,
#           'temp_max': 298.375,
#           'temp_min': 298.375},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'message': 0.004,
#          'sunrise': 1520239546,
#          'sunset': 1520284371},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 335.502, 'speed': 1.12}}
# city generated: bardiyah,ly
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB28ED240>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: biak,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB23D0EF0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -0.91, 'lon': 122.88},
#  'dt': 1520222109,
#  'id': 1637001,
#  'main': {'grnd_level': 1008.25,
#           'humidity': 100,
#           'pressure': 1008.25,
#           'sea_level': 1024.18,
#           'temp': 297.1,
#           'temp_max': 297.1,
#           'temp_min': 297.1},
#  'name': 'Biak',
#  'rain': {'3h': 6.16},
#  'sys': {'country': 'ID',
#          'message': 0.0037,
#          'sunrise': 1520200578,
#          'sunset': 1520244220},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 225.002, 'speed': 1.92}}
# duplicate city: hermanus,za
# city generated: mys shmidta,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3161D68>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: bredasdorp,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3839CC0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1520218800,
#  'id': 1015776,
#  'main': {'humidity': 83,
#           'pressure': 1014,
#           'temp': 294.15,
#           'temp_max': 294.15,
#           'temp_min': 294.15},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 6591,
#          'message': 0.0034,
#          'sunrise': 1520224237,
#          'sunset': 1520269883,
#          'type': 1},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 2.6}}
# city generated: shenavan,am
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0AC4240>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 40.05, 'lon': 43.92},
#  'dt': 1520218800,
#  'id': 616231,
#  'main': {'humidity': 66,
#           'pressure': 1004,
#           'temp': 284.15,
#           'temp_max': 284.15,
#           'temp_min': 284.15},
#  'name': 'Shenavan',
#  'sys': {'country': 'TR',
#          'id': 7226,
#          'message': 0.0039,
#          'sunrise': 1520220711,
#          'sunset': 1520262021,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 2.1}}
# city generated: ilulissat,gl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB22133C8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: airai,pw
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2E4E5C0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -8.93, 'lon': 125.41},
#  'dt': 1520222110,
#  'id': 1651810,
#  'main': {'grnd_level': 945.42,
#           'humidity': 91,
#           'pressure': 945.42,
#           'sea_level': 1021.75,
#           'temp': 298.325,
#           'temp_max': 298.325,
#           'temp_min': 298.325},
#  'name': 'Airai',
#  'rain': {'3h': 2.67},
#  'sys': {'country': 'TL',
#          'message': 0.005,
#          'sunrise': 1520199760,
#          'sunset': 1520243817},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 221.502, 'speed': 0.77}}
# city generated: laguna,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0C697F0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 27.52, 'lon': -110.01},
#  'dt': 1520222065,
#  'id': 4013704,
#  'main': {'grnd_level': 1005.81,
#           'humidity': 31,
#           'pressure': 1005.81,
#           'sea_level': 1027.26,
#           'temp': 292.275,
#           'temp_max': 292.275,
#           'temp_min': 292.275},
#  'name': 'Laguna',
#  'sys': {'country': 'MX',
#          'message': 0.004,
#          'sunrise': 1520257198,
#          'sunset': 1520299394},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 275.002, 'speed': 2.12}}
# city generated: sawakin,sd
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB32B2978>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 19.1, 'lon': 37.33},
#  'dt': 1520222111,
#  'id': 367544,
#  'main': {'grnd_level': 998.52,
#           'humidity': 100,
#           'pressure': 998.52,
#           'sea_level': 1025.4,
#           'temp': 292.85,
#           'temp_max': 292.85,
#           'temp_min': 292.85},
#  'name': 'Sawakin',
#  'sys': {'country': 'SD',
#          'message': 0.0057,
#          'sunrise': 1520221622,
#          'sunset': 1520264250},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 294.502, 'speed': 2.27}}
# city generated: qaanaaq,gl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2213860>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: punta arenas,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1DA7C88>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1520218800,
#  'id': 3874787,
#  'main': {'humidity': 70,
#           'pressure': 1003,
#           'temp': 282.15,
#           'temp_max': 282.15,
#           'temp_min': 282.15},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 4642,
#          'message': 0.0089,
#          'sunrise': 1520245055,
#          'sunset': 1520292679,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 10.8}}
# duplicate city: dikson,ru
# city generated: snezhnogorsk,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3204F98>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 69.19, 'lon': 33.23},
#  'dt': 1520218800,
#  'id': 795243,
#  'main': {'humidity': 69,
#           'pressure': 1015,
#           'temp': 251.15,
#           'temp_max': 251.15,
#           'temp_min': 251.15},
#  'name': 'Snezhnogorsk',
#  'sys': {'country': 'RU',
#          'id': 7268,
#          'message': 0.0035,
#          'sunrise': 1520225592,
#          'sunset': 1520262340,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 2}}
# city generated: wanning,cn
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1E10668>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 48.64, 'lon': 13.53},
#  'dt': 1520220000,
#  'id': 3220813,
#  'main': {'humidity': 86,
#           'pressure': 1001,
#           'temp': 270.15,
#           'temp_max': 270.15,
#           'temp_min': 270.15},
#  'name': 'Wanning',
#  'sys': {'country': 'AT',
#          'id': 5932,
#          'message': 0.0046,
#          'sunrise': 1520228383,
#          'sunset': 1520268946,
#          'type': 1},
#  'visibility': 4900,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'speed': 1}}
# city generated: hilo,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB34E7CF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1520218380,
#  'id': 5855927,
#  'main': {'humidity': 61,
#           'pressure': 1015,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 818,
#          'message': 0.0038,
#          'sunrise': 1520267792,
#          'sunset': 1520310423,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 3.1}}
# city generated: constitucion,mx
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB297D198>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 23.99, 'lon': -104.67},
#  'dt': 1520218080,
#  'id': 4011743,
#  'main': {'humidity': 20,
#           'pressure': 1022,
#           'temp': 292.15,
#           'temp_max': 292.15,
#           'temp_min': 292.15},
#  'name': 'Constitucion',
#  'sys': {'country': 'MX',
#          'id': 3983,
#          'message': 0.0033,
#          'sunrise': 1520255817,
#          'sunset': 1520298210,
#          'type': 1},
#  'visibility': 12874,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 1.5}}
# duplicate city: bredasdorp,za
# city generated: saskylakh,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB31E2E10>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 71.97, 'lon': 114.09},
#  'dt': 1520222052,
#  'id': 2017155,
#  'main': {'grnd_level': 1021.54,
#           'humidity': 77,
#           'pressure': 1021.54,
#           'sea_level': 1034.76,
#           'temp': 245.525,
#           'temp_max': 245.525,
#           'temp_min': 245.525},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU',
#          'message': 0.0041,
#          'sunrise': 1520206829,
#          'sunset': 1520242312},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238.002, 'speed': 2.52}}
# duplicate city: mataura,pf
# city generated: belushya guba,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3059240>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: alofi,nu
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2AF7B70>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: san patricio,mx
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB29F6EB8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -26.98, 'lon': -56.83},
#  'dt': 1520222086,
#  'id': 3437029,
#  'main': {'grnd_level': 1011.81,
#           'humidity': 92,
#           'pressure': 1011.81,
#           'sea_level': 1021.71,
#           'temp': 294.775,
#           'temp_max': 294.775,
#           'temp_min': 294.775},
#  'name': 'San Patricio',
#  'sys': {'country': 'PY',
#          'message': 0.0031,
#          'sunrise': 1520242972,
#          'sunset': 1520288049},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 91.0019, 'speed': 1.07}}
# city generated: miranda,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0C80278>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 3.25, 'lon': -76.23},
#  'dt': 1520218800,
#  'id': 3674702,
#  'main': {'humidity': 78,
#           'pressure': 1015,
#           'temp': 295.15,
#           'temp_max': 295.15,
#           'temp_min': 295.15},
#  'name': 'Miranda',
#  'sys': {'country': 'CO',
#          'id': 4251,
#          'message': 0.0056,
#          'sunrise': 1520248461,
#          'sunset': 1520291898,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 3.1}}
# city generated: cape town,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB383B2E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1520218800,
#  'id': 3369157,
#  'main': {'humidity': 72,
#           'pressure': 1011,
#           'temp': 293.15,
#           'temp_max': 293.15,
#           'temp_min': 293.15},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 6529,
#          'message': 0.0051,
#          'sunrise': 1520224650,
#          'sunset': 1520270248,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 10.3}}
# city generated: plouzane,fr
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB21509B0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: portland,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0B0ACC0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.52, 'lon': -122.67},
#  'dt': 1520219940,
#  'id': 5746545,
#  'main': {'humidity': 75,
#           'pressure': 1026,
#           'temp': 280.52,
#           'temp_max': 282.15,
#           'temp_min': 279.15},
#  'name': 'Portland',
#  'sys': {'country': 'US',
#          'id': 2274,
#          'message': 0.0041,
#          'sunrise': 1520260876,
#          'sunset': 1520301813,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 230, 'speed': 3.6}}
# duplicate city: dikson,ru
# city generated: hasaki,jp
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB26CF160>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: mirabad,af
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0A997B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 28.27, 'lon': 61.33},
#  'dt': 1520222118,
#  'id': 1160571,
#  'main': {'grnd_level': 864.77,
#           'humidity': 73,
#           'pressure': 864.77,
#           'sea_level': 1030.26,
#           'temp': 275.125,
#           'temp_max': 275.125,
#           'temp_min': 275.125},
#  'name': 'Mirabad',
#  'sys': {'country': 'IR',
#          'message': 0.0038,
#          'sunrise': 1520216129,
#          'sunset': 1520258234},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 51.0019, 'speed': 1.02}}
# city generated: jamestown,sh
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB32C6F98>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1520222035,
#  'id': 2069194,
#  'main': {'grnd_level': 974.77,
#           'humidity': 71,
#           'pressure': 974.77,
#           'sea_level': 1033.34,
#           'temp': 291.725,
#           'temp_max': 291.725,
#           'temp_min': 291.725},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0035,
#          'sunrise': 1520195819,
#          'sunset': 1520241403},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 134.002, 'speed': 5.32}}
# duplicate city: hilo,us
# duplicate city: busselton,au
# duplicate city: busselton,au
# city generated: jibuti,dj
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB20212E8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: rayong,th
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3339E80>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 12.68, 'lon': 101.28},
#  'dt': 1520218800,
#  'id': 1607017,
#  'main': {'humidity': 66,
#           'pressure': 1011,
#           'temp': 303.15,
#           'temp_max': 303.15,
#           'temp_min': 303.15},
#  'name': 'Rayong',
#  'sys': {'country': 'TH',
#          'id': 7926,
#          'message': 0.0176,
#          'sunrise': 1520206111,
#          'sunset': 1520249065,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 4.1}}
# city generated: itaituba,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0C51C50>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -4.26, 'lon': -55.99},
#  'dt': 1520222119,
#  'id': 3397967,
#  'main': {'grnd_level': 1011.89,
#           'humidity': 93,
#           'pressure': 1011.89,
#           'sea_level': 1021.87,
#           'temp': 297.975,
#           'temp_max': 297.975,
#           'temp_min': 297.975},
#  'name': 'Itaituba',
#  'sys': {'country': 'BR',
#          'message': 0.0045,
#          'sunrise': 1520243417,
#          'sunset': 1520287222},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30.5019, 'speed': 0.97}}
# city generated: taolanaro,mg
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2900C88>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: atuona,pf
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2B5B5C0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: provideniya,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB31CA0F0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1520218800,
#  'id': 4031574,
#  'main': {'humidity': 94,
#           'pressure': 1009,
#           'temp': 273.15,
#           'temp_max': 273.15,
#           'temp_min': 273.15},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'id': 7239,
#          'message': 0.004,
#          'sunrise': 1520274322,
#          'sunset': 1520312676,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 170, 'speed': 6}}
# city generated: lebu,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1DA4898>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1520218800,
#  'id': 344979,
#  'main': {'humidity': 87,
#           'pressure': 1025,
#           'temp': 285.15,
#           'temp_max': 285.15,
#           'temp_min': 285.15},
#  'name': 'Lebu',
#  'sys': {'country': 'ET',
#          'id': 6338,
#          'message': 0.0032,
#          'sunrise': 1520221022,
#          'sunset': 1520264171,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 2.1}}
# city generated: mahebourg,mu
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2937128>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: nikolskoye,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB316EF60>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1520218800,
#  'id': 546105,
#  'main': {'humidity': 84,
#           'pressure': 1010,
#           'temp': 260.15,
#           'temp_max': 260.15,
#           'temp_min': 260.15},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 7267,
#          'message': 0.0037,
#          'sunrise': 1520224991,
#          'sunset': 1520264078,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 48.5019, 'speed': 2.27}}
# city generated: port alfred,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3848940>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: ushuaia,ar
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0ADCC88>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1520218800,
#  'id': 3833367,
#  'main': {'humidity': 81,
#           'pressure': 997,
#           'temp': 279.15,
#           'temp_max': 279.15,
#           'temp_min': 279.15},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 4754,
#          'message': 0.0048,
#          'sunrise': 1520244295,
#          'sunset': 1520292186,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 312.002, 'speed': 6.37}}
# city generated: isangel,vu
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB382AEF0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: san vicente,ph
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2D4A080>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 13.64, 'lon': -88.78},
#  'dt': 1520218200,
#  'id': 3583178,
#  'main': {'humidity': 78,
#           'pressure': 1015,
#           'temp': 297.15,
#           'temp_max': 299.15,
#           'temp_min': 295.15},
#  'name': 'San Vicente',
#  'sys': {'country': 'SV',
#          'id': 4205,
#          'message': 0.0033,
#          'sunrise': 1520251731,
#          'sunset': 1520294660,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 5.00192, 'speed': 0.92}}
# duplicate city: hermanus,za
# duplicate city: rikitea,pf
# city generated: vaini,to
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB335A2E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1520222029,
#  'id': 1273574,
#  'main': {'grnd_level': 960.26,
#           'humidity': 63,
#           'pressure': 960.26,
#           'sea_level': 1025.24,
#           'temp': 295.625,
#           'temp_max': 295.625,
#           'temp_min': 295.625},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'message': 0.0041,
#          'sunrise': 1520212608,
#          'sunset': 1520255428},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70.5019, 'speed': 1.67}}
# city generated: amderma,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3038390>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: port elizabeth,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB38489E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.31, 'lon': -74.98},
#  'dt': 1520218560,
#  'id': 4501427,
#  'main': {'humidity': 37,
#           'pressure': 1021,
#           'temp': 274.82,
#           'temp_max': 276.15,
#           'temp_min': 274.15},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'US',
#          'id': 1971,
#          'message': 0.0041,
#          'sunrise': 1520249188,
#          'sunset': 1520290606,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'gust': 11.3, 'speed': 7.2}}
# city generated: luderitz,na
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2A5B4A8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: khatanga,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB30E1940>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1520222039,
#  'id': 2022572,
#  'main': {'grnd_level': 1029.89,
#           'humidity': 67,
#           'pressure': 1029.89,
#           'sea_level': 1035.17,
#           'temp': 247.15,
#           'temp_max': 247.15,
#           'temp_min': 247.15},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU',
#          'message': 0.0029,
#          'sunrise': 1520209610,
#          'sunset': 1520245108},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 247.502, 'speed': 4.92}}
# city generated: kuhestan,af
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0A994A8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: saint-philippe,re
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2E67D30>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.36, 'lon': -73.48},
#  'dt': 1520220540,
#  'id': 6138908,
#  'main': {'humidity': 96,
#           'pressure': 1023,
#           'temp': 272.88,
#           'temp_max': 273.15,
#           'temp_min': 272.15},
#  'name': 'Saint-Philippe',
#  'sys': {'country': 'CA',
#          'id': 3851,
#          'message': 0.0066,
#          'sunrise': 1520249078,
#          'sunset': 1520290004,
#          'type': 1},
#  'visibility': 9656,
#  'weather': [{'description': 'light shower snow',
#               'icon': '13n',
#               'id': 620,
#               'main': 'Snow'}],
#  'wind': {'deg': 350, 'speed': 4.6}}
# duplicate city: amderma,ru
# duplicate city: jamestown,sh
# duplicate city: bredasdorp,za
# city generated: rawson,ar
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0AD8780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -43.3, 'lon': -65.11},
#  'dt': 1520222127,
#  'id': 3839307,
#  'main': {'grnd_level': 1017.32,
#           'humidity': 40,
#           'pressure': 1017.32,
#           'sea_level': 1028.48,
#           'temp': 284.85,
#           'temp_max': 284.85,
#           'temp_min': 284.85},
#  'name': 'Rawson',
#  'sys': {'country': 'AR',
#          'message': 0.0033,
#          'sunrise': 1520244288,
#          'sunset': 1520290684},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280.002, 'speed': 4.02}}
# duplicate city: ushuaia,ar
# city generated: pevek,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB31AEA90>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 69.7, 'lon': 170.27},
#  'dt': 1520222128,
#  'id': 2122090,
#  'main': {'grnd_level': 1023.56,
#           'humidity': 93,
#           'pressure': 1023.56,
#           'sea_level': 1031.6,
#           'temp': 251.175,
#           'temp_max': 251.175,
#           'temp_min': 251.175},
#  'name': 'Pevek',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1520192900,
#          'sunset': 1520229265},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 358.002, 'speed': 0.67}}
# duplicate city: hermanus,za
# duplicate city: port alfred,za
# city generated: ponta do sol,cv
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1EDFE80>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -20.63, 'lon': -46},
#  'dt': 1520222128,
#  'id': 3453439,
#  'main': {'grnd_level': 922.48,
#           'humidity': 94,
#           'pressure': 922.48,
#           'sea_level': 1022.12,
#           'temp': 293.475,
#           'temp_max': 293.475,
#           'temp_min': 293.475},
#  'name': 'Ponta do Sol',
#  'rain': {'3h': 0.48},
#  'sys': {'country': 'BR',
#          'message': 0.0055,
#          'sunrise': 1520240573,
#          'sunset': 1520285257},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 191.502, 'speed': 0.77}}
# duplicate city: port elizabeth,za
# city generated: illoqqortoormiut,gl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB22132E8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: bilma,ne
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2A65320>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.69, 'lon': 12.92},
#  'dt': 1520222129,
#  'id': 2446796,
#  'main': {'grnd_level': 965.2,
#           'humidity': 38,
#           'pressure': 965.2,
#           'sea_level': 1023.37,
#           'temp': 287.85,
#           'temp_max': 287.85,
#           'temp_min': 287.85},
#  'name': 'Bilma',
#  'sys': {'country': 'NE',
#          'message': 0.0046,
#          'sunrise': 1520227466,
#          'sunset': 1520270121},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 180.502, 'speed': 1.22}}
# ...
#          'sunrise': 1520223387,
#          'sunset': 1520268590,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 330, 'speed': 1.5}}
# duplicate city: ushuaia,ar
# duplicate city: kodiak,us
# duplicate city: baykit,ru
# duplicate city: qaanaaq,gl
# city generated: yuancheng,cn
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1E215C0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: hithadhoo,mv
# duplicate city: avarua,ck
# duplicate city: codrington,ag
# duplicate city: mahebourg,mu
# duplicate city: jamestown,sh
# duplicate city: kropotkin,ru
# duplicate city: bengkulu,id
# city generated: skalistyy,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3200AC8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: katsuura,jp
# duplicate city: chokurdakh,ru
# duplicate city: moron,mn
# duplicate city: tuy hoa,vn
# city generated: humaita,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0C427B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -24.93, 'lon': -65.37},
#  'dt': 1520218800,
#  'id': 3838233,
#  'main': {'humidity': 77,
#           'pressure': 1014,
#           'temp': 295.96,
#           'temp_max': 297.15,
#           'temp_min': 294.15},
#  'name': 'Humaita',
#  'sys': {'country': 'AR',
#          'id': 4729,
#          'message': 0.0039,
#          'sunrise': 1520245091,
#          'sunset': 1520290031,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11n',
#               'id': 211,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 293.002, 'speed': 1.07}}
# duplicate city: oussouye,sn
# city generated: liniere,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0D4AD68>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: butaritari,ki
# city generated: manono,cd
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB1D5C9E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -7.3, 'lon': 27.4},
#  'dt': 1520223135,
#  'id': 209598,
#  'main': {'grnd_level': 953.53,
#           'humidity': 100,
#           'pressure': 953.53,
#           'sea_level': 1024.26,
#           'temp': 292.075,
#           'temp_max': 292.075,
#           'temp_min': 292.075},
#  'name': 'Manono',
#  'sys': {'country': 'CD',
#          'message': 0.0036,
#          'sunrise': 1520223326,
#          'sunset': 1520267290},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 113.002, 'speed': 1.57}}
# duplicate city: komsomolskiy,ru
# duplicate city: ponta do sol,pt
# city generated: gwadar,pk
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2DA83C8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: ushuaia,ar
# duplicate city: ahipara,nz
# duplicate city: albany,au
# city generated: hue,vn
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB38253C8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 16.47, 'lon': 107.58},
#  'dt': 1520220600,
#  'id': 1580240,
#  'main': {'humidity': 63,
#           'pressure': 1011,
#           'temp': 307.15,
#           'temp_max': 307.15,
#           'temp_min': 307.15},
#  'name': 'Hue',
#  'sys': {'country': 'VN',
#          'id': 7982,
#          'message': 0.0033,
#          'sunrise': 1520204699,
#          'sunset': 1520247456,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 2.1}}
# duplicate city: hobart,au
# duplicate city: codrington,ag
# duplicate city: hithadhoo,mv
# city generated: sabla,bg
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0BB4978>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 12.75, 'lon': 4.71},
#  'dt': 1520223136,
#  'id': 2349431,
#  'main': {'grnd_level': 988.47,
#           'humidity': 26,
#           'pressure': 988.47,
#           'sea_level': 1021.43,
#           'temp': 295.25,
#           'temp_max': 295.25,
#           'temp_min': 295.25},
#  'name': 'Sabla',
#  'sys': {'country': 'NG',
#          'message': 0.0031,
#          'sunrise': 1520229280,
#          'sunset': 1520272242},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 19.5019, 'speed': 4.67}}
# duplicate city: barrow,us
# duplicate city: hermanus,za
# city generated: voroshnevo,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB32784A8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: irricana,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0D42780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 51.32, 'lon': -113.6},
#  'dt': 1520222400,
#  'id': 5984019,
#  'main': {'humidity': 77,
#           'pressure': 1019,
#           'temp': 254.43,
#           'temp_max': 259.15,
#           'temp_min': 250.15},
#  'name': 'Irricana',
#  'sys': {'country': 'CA',
#          'id': 3145,
#          'message': 0.0046,
#          'sunrise': 1520258993,
#          'sunset': 1520299353,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1}}
# duplicate city: ketchikan,us
# duplicate city: cabo san lucas,mx
# city generated: araouane,ml
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB29138D0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.9, 'lon': -3.53},
#  'dt': 1520223137,
#  'id': 2460954,
#  'main': {'grnd_level': 990.9,
#           'humidity': 43,
#           'pressure': 990.9,
#           'sea_level': 1024.79,
#           'temp': 291.475,
#           'temp_max': 291.475,
#           'temp_min': 291.475},
#  'name': 'Araouane',
#  'sys': {'country': 'ML',
#          'message': 0.003,
#          'sunrise': 1520231417,
#          'sunset': 1520274064},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 18.5019, 'speed': 1.27}}
# city generated: balikpapan,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB23CDCF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -1.24, 'lon': 116.86},
#  'dt': 1520222910,
#  'id': 1650527,
#  'main': {'grnd_level': 1023.4,
#           'humidity': 98,
#           'pressure': 1023.4,
#           'sea_level': 1024.14,
#           'temp': 302,
#           'temp_max': 302,
#           'temp_min': 302},
#  'name': 'Balikpapan',
#  'sys': {'country': 'ID',
#          'message': 0.0041,
#          'sunrise': 1520202014,
#          'sunset': 1520245672},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 335.502, 'speed': 2.87}}
# duplicate city: egvekinot,ru
# city generated: ivanino,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB30C0940>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 51.65, 'lon': 35.58},
#  'dt': 1520220600,
#  'id': 555617,
#  'main': {'humidity': 85,
#           'pressure': 999,
#           'temp': 261.15,
#           'temp_max': 261.15,
#           'temp_min': 261.15},
#  'name': 'Ivanino',
#  'sys': {'country': 'RU',
#          'id': 7327,
#          'message': 0.0033,
#          'sunrise': 1520223263,
#          'sunset': 1520263488,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 300, 'speed': 6}}
# duplicate city: port alfred,za
# duplicate city: cape town,za
# duplicate city: qaanaaq,gl
# city generated: la reforma,mx
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB29B7358>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 14.8, 'lon': -91.82},
#  'dt': 1520217600,
#  'id': 3594143,
#  'main': {'humidity': 83,
#           'pressure': 1012,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'La Reforma',
#  'sys': {'country': 'GT',
#          'id': 4019,
#          'message': 0.0086,
#          'sunrise': 1520252490,
#          'sunset': 1520295361,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 145.502, 'speed': 0.42}}
# duplicate city: iberia,pe
# duplicate city: barentsburg,sj
# duplicate city: bluff,nz
# duplicate city: yellowknife,ca
# city generated: matara,lk
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB28B4898>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -13.74, 'lon': -72.9},
#  'dt': 1520223140,
#  'id': 3948642,
#  'main': {'grnd_level': 671.36,
#           'humidity': 95,
#           'pressure': 671.36,
#           'sea_level': 1022.72,
#           'temp': 280.15,
#           'temp_max': 280.15,
#           'temp_min': 280.15},
#  'name': 'Matara',
#  'rain': {'3h': 0.35},
#  'sys': {'country': 'PE',
#          'message': 0.0049,
#          'sunrise': 1520247227,
#          'sunset': 1520291519},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 210.002, 'speed': 0.82}}
# duplicate city: port lincoln,au
# duplicate city: vila velha,br
# duplicate city: grants,us
# duplicate city: bilma,ne
# duplicate city: hermanus,za
# duplicate city: avarua,ck
# duplicate city: aklavik,ca
# duplicate city: bredasdorp,za
# duplicate city: bluff,nz
# duplicate city: avarua,ck
# duplicate city: torbay,ca
# duplicate city: mergui,mm
# duplicate city: tsihombe,mg
# duplicate city: biltine,td
# duplicate city: codrington,ag
# duplicate city: cape town,za
# duplicate city: sao filipe,cv
# duplicate city: taltal,cl
# duplicate city: leningradskiy,ru
# duplicate city: victoria,sc
# duplicate city: thompson,ca
# duplicate city: kahului,us
# duplicate city: narsaq,gl
# duplicate city: carnarvon,au
# duplicate city: kapaa,us
# duplicate city: sao joao da barra,br
# duplicate city: ancud,cl
# duplicate city: butaritari,ki
# city generated: fianga,td
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB3318B70>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: asfi,ma
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB28F08D0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: porto tolle,it
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB2682EB8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: malwan,in
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB252E048>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: kodiak,us
# duplicate city: new norfolk,au
# duplicate city: hilo,us
# duplicate city: avarua,ck
# duplicate city: kavaratti,in
# duplicate city: chokurdakh,ru
# city generated: srandakan,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB23FEEB8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: busselton,au
# duplicate city: aklavik,ca
# duplicate city: souillac,mu
# duplicate city: punta arenas,cl
# duplicate city: rocha,uy
# city generated: stoyba,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB321BFD0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: nikolskoye,ru
# duplicate city: cape town,za
# duplicate city: bengkulu,id
# city generated: gloversville,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB27C9860>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 43.05, 'lon': -74.34},
#  'dt': 1520221980,
#  'id': 5118743,
#  'main': {'humidity': 67,
#           'pressure': 1020,
#           'temp': 272.64,
#           'temp_max': 273.15,
#           'temp_min': 272.15},
#  'name': 'Gloversville',
#  'sys': {'country': 'US',
#          'id': 2088,
#          'message': 0.0046,
#          'sunrise': 1520249182,
#          'sunset': 1520290309,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 330, 'speed': 4.1}}
# duplicate city: punta arenas,cl
# duplicate city: kruisfontein,za
# duplicate city: coquimbo,cl
# duplicate city: barrow,us
# city generated: glendive,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB278F320>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 47.11, 'lon': -104.71},
#  'dt': 1520222100,
#  'id': 5654391,
#  'main': {'humidity': 107,
#           'pressure': 1009,
#           'temp': 269.15,
#           'temp_max': 269.15,
#           'temp_min': 269.15},
#  'name': 'Glendive',
#  'sys': {'country': 'US',
#          'id': 1846,
#          'message': 0.0034,
#          'sunrise': 1520256644,
#          'sunset': 1520297428,
#          'type': 1},
#  'visibility': 8047,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 291.002, 'speed': 7.87}}
# duplicate city: mahebourg,mu
# duplicate city: harper,lr
# duplicate city: hobart,au
# duplicate city: amderma,ru
# duplicate city: saldanha,za
# duplicate city: butaritari,ki
# duplicate city: kieta,pg
# duplicate city: taolanaro,mg
# duplicate city: araouane,ml
# duplicate city: rikitea,pf
# duplicate city: rikitea,pf
# city generated: davidson,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001DEB0D2EA20>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 35.5, 'lon': -80.85},
#  'dt': 1520222040,
#  'id': 4463053,
#  'main': {'humidity': 60,
#           'pressure': 1021,
#           'temp': 276.48,
#           'temp_max': 278.15,
#           'temp_min': 274.15},
#  'name': 'Davidson',
#  'sys': {'country': 'US',
#          'id': 1784,
#          'message': 0.0043,
#          'sunrise': 1520250457,
#          'sunset': 1520292149,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 8.50192, 'speed': 4.22}}

# %% [markdown]
# ## Merge data into Pandas DataFrame
#
# first we'll parse out the weather records into lists.

# %%
import pandas as pd
