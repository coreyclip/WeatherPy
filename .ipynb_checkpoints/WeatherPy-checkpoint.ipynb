# %% [markdown]
# ## Randomly select at least 1000 unique (non-repeat) cities based on latitude and longitude. And perform a weather check on each of the cities using a series of successive API calls
#
# First we'll create a empty set to hold our city names, python sets do not accept duplicate datapoints which means we don't have to check for duplicates later. longitude ranges from -180 to 180 while latitude ranges from -90 to 90. We use the **random** library's **uniform** function to randomly pick pairings of lat and long values to put into the **citipy** function. The outputed *city names* and *country codes* will be inserted into the *set*. These same city name, country code pairs are sent to the OpenWeatherMaps API and if a city's weather report is found, (https status code 200) it'll be stored in the weather list.  We'll put this all under a **while** loop to keep on generating coordinates and cities until we fill up our weather list with 1000 unique values.

# %%
from citipy import citipy
from random import uniform # Draw samples from a uniform distribution
import requests
from pprint import pprint
from config import key
url = 'http://api.openweathermap.org/data/2.5/weather?'
cities = list()
weather = list()
duplicate_cities = list()
weatherless_cities = set()
while len(weather) < 1001:
    # generate a 1000 unique latitude and longitude values
    
    long = round(uniform(-180,180), 3) #longitude ranges from -180 to 180
    lat = round(uniform(-90, 90), 3) #latitude ranges from -90 to 90
    #feed into citipy the lat, long coordinates to return as city object
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code
    
    # add the city and it's country code to the cities set
    city_entry = f"{city_name},{country_code}"
    if city_entry not in cities:
        cities.append(city_entry)
        print(f"city generated: {city_entry}")
        payload = url + f"{city}"
        keyed_payload = url + "appid=" + key + "&q=" + city_entry + "?" + "&units=metric"
        print(f"processing request for {payload}")

        response = requests.get(keyed_payload)
        weather_json = response.json()
        print("associated weather data: \n")
        pprint(weather_json)
        if weather_json['cod'] == 200:
            weather.append(weather_json)
        elif weather_json['cod'] == 404:
            weatherless_cities.add(city_entry)
        else:
            pass
    else:
        print(f"duplicate city: {city_entry}")
        duplicate_cities.append(city_entry)
# Out:
# city generated: kaitangata,nz
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814B652E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1523689063,
#  'id': 2208248,
#  'main': {'grnd_level': 1009.92,
#           'humidity': 75,
#           'pressure': 1009.92,
#           'sea_level': 1026.99,
#           'temp': 9.06,
#           'temp_max': 9.06,
#           'temp_min': 9.06},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'message': 0.0038,
#          'sunrise': 1523646939,
#          'sunset': 1523685929},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 58.5051, 'speed': 7.34}}
# city generated: albany,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B326D8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1523685240,
#  'id': 5106834,
#  'main': {'humidity': 75,
#           'pressure': 1013,
#           'temp': 8.51,
#           'temp_max': 9,
#           'temp_min': 8},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 2088,
#          'message': 0.0043,
#          'sunrise': 1523700890,
#          'sunset': 1523748975,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 1.5}}
# city generated: tak,th
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8153A4908>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 16.87, 'lon': 99.12},
#  'dt': 1523685600,
#  'id': 1150490,
#  'main': {'humidity': 27,
#           'pressure': 1009,
#           'temp': 38,
#           'temp_max': 38,
#           'temp_min': 38},
#  'name': 'Tak',
#  'sys': {'country': 'TH',
#          'id': 7940,
#          'message': 0.0037,
#          'sunrise': 1523660928,
#          'sunset': 1523705941,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 4.1}}
# city generated: vaini,to
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8153BEF60>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1523689065,
#  'id': 1273574,
#  'main': {'grnd_level': 958.85,
#           'humidity': 34,
#           'pressure': 958.85,
#           'sea_level': 1022.94,
#           'temp': 34.31,
#           'temp_max': 34.31,
#           'temp_min': 34.31},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'message': 0.0034,
#          'sunrise': 1523666904,
#          'sunset': 1523711783},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 105.005, 'speed': 0.84}}
# city generated: sumter,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81485FEF0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.92, 'lon': -80.34},
#  'dt': 1523686500,
#  'id': 4597948,
#  'main': {'humidity': 88,
#           'pressure': 1020,
#           'temp': 16.22,
#           'temp_max': 18,
#           'temp_min': 15},
#  'name': 'Sumter',
#  'sys': {'country': 'US',
#          'id': 2438,
#          'message': 0.0041,
#          'sunrise': 1523703085,
#          'sunset': 1523749929,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 2.1}}
# city generated: rikitea,pf
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814BC5710>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: katsuura,jp
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81474BA90>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.93, 'lon': 134.5},
#  'dt': 1523685780,
#  'id': 1865309,
#  'main': {'humidity': 68,
#           'pressure': 1012,
#           'temp': 18,
#           'temp_max': 18,
#           'temp_min': 18},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 7584,
#          'message': 0.004,
#          'sunrise': 1523651567,
#          'sunset': 1523698341,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 170, 'gust': 15.9, 'speed': 10.8}}
# city generated: bluff,nz
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814B5ECC0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1523689066,
#  'id': 2175403,
#  'main': {'grnd_level': 1003.84,
#           'humidity': 85,
#           'pressure': 1003.84,
#           'sea_level': 1026.58,
#           'temp': 20.46,
#           'temp_max': 20.46,
#           'temp_min': 20.46},
#  'name': 'Bluff',
#  'rain': {'3h': 0.81455},
#  'sys': {'country': 'AU',
#          'message': 0.0041,
#          'sunrise': 1523650613,
#          'sunset': 1523692251},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 55.0051, 'speed': 2.34}}
# city generated: hilo,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81554E9B0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1523685180,
#  'id': 5855927,
#  'main': {'humidity': 83,
#           'pressure': 1018,
#           'temp': 22,
#           'temp_max': 22,
#           'temp_min': 22},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 818,
#          'message': 0.0033,
#          'sunrise': 1523721774,
#          'sunset': 1523767093,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 2.1}}
# duplicate city: bluff,nz
# city generated: port alfred,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8158AF5F8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: udachnyy,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8152B2208>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: souillac,mu
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8149A26D8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.6, 'lon': -0.6},
#  'dt': 1523687400,
#  'id': 3026644,
#  'main': {'humidity': 100,
#           'pressure': 1015,
#           'temp': 10.45,
#           'temp_max': 11,
#           'temp_min': 10},
#  'name': 'Souillac',
#  'sys': {'country': 'FR',
#          'id': 5528,
#          'message': 0.0033,
#          'sunrise': 1523683106,
#          'sunset': 1523731658,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 1.5}}
# city generated: hobart,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B3F048>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1523687400,
#  'id': 2163355,
#  'main': {'humidity': 41,
#           'pressure': 978,
#           'temp': 15,
#           'temp_max': 15,
#           'temp_min': 15},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0035,
#          'sunrise': 1523652097,
#          'sunset': 1523691583,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 9.8}}
# city generated: xinzhi,cn
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813E7F390>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 22.54, 'lon': 120.62},
#  'dt': 1523685600,
#  'id': 1670479,
#  'main': {'humidity': 59,
#           'pressure': 1010,
#           'temp': 30.64,
#           'temp_max': 32,
#           'temp_min': 29},
#  'name': 'Xinzhi',
#  'sys': {'country': 'TW',
#          'id': 7485,
#          'message': 0.0036,
#          'sunrise': 1523655509,
#          'sunset': 1523701047,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 5.7}}
# duplicate city: port alfred,za
# city generated: dingle,ie
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814478710>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 11, 'lon': 122.67},
#  'dt': 1523689068,
#  'id': 1714733,
#  'main': {'grnd_level': 1000.76,
#           'humidity': 52,
#           'pressure': 1000.76,
#           'sea_level': 1020.79,
#           'temp': 33.16,
#           'temp_max': 33.16,
#           'temp_min': 33.16},
#  'name': 'Dingle',
#  'sys': {'country': 'PH',
#          'message': 0.004,
#          'sunrise': 1523655532,
#          'sunset': 1523700030},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 55.5051, 'speed': 5.64}}
# city generated: barrow,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8154AEBE0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1523688832,
#  'id': 3833859,
#  'main': {'grnd_level': 1029.61,
#           'humidity': 87,
#           'pressure': 1029.61,
#           'sea_level': 1042.07,
#           'temp': 7.46,
#           'temp_max': 7.46,
#           'temp_min': 7.46},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.0031,
#          'sunrise': 1523701645,
#          'sunset': 1523741652},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 16.0051, 'speed': 4.29}}
# city generated: dikson,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150F2438>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: victoria,sc
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815314FD0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1523687400,
#  'id': 1733782,
#  'main': {'humidity': 74,
#           'pressure': 1005,
#           'temp': 31.51,
#           'temp_max': 32,
#           'temp_min': 31},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 8115,
#          'message': 0.0039,
#          'sunrise': 1523657549,
#          'sunset': 1523701573,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 3.6}}
# city generated: moranbah,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B41D68>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -22, 'lon': 148.04},
#  'dt': 1523689069,
#  'id': 6533368,
#  'main': {'grnd_level': 992.25,
#           'humidity': 99,
#           'pressure': 992.25,
#           'sea_level': 1025.85,
#           'temp': 18.91,
#           'temp_max': 18.91,
#           'temp_min': 18.91},
#  'name': 'Moranbah',
#  'rain': {'3h': 9.18392},
#  'sys': {'country': 'AU',
#          'message': 0.0204,
#          'sunrise': 1523650790,
#          'sunset': 1523692570},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 143.505, 'speed': 6.34}}
# city generated: alofi,nu
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814B5E828>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: albany,au
# city generated: castro,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813E080B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -42.48, 'lon': -73.76},
#  'dt': 1523689070,
#  'id': 3896218,
#  'main': {'grnd_level': 1015.43,
#           'humidity': 90,
#           'pressure': 1015.43,
#           'sea_level': 1030.15,
#           'temp': 10.26,
#           'temp_max': 10.26,
#           'temp_min': 10.26},
#  'name': 'Castro',
#  'rain': {'3h': 0.20871},
#  'sys': {'country': 'CL',
#          'message': 0.0034,
#          'sunrise': 1523705172,
#          'sunset': 1523744614},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 7.50513, 'speed': 3.61}}
# city generated: barentsburg,sj
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81533F2B0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: nikki,bj
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813BFE9B0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 9.94, 'lon': 3.21},
#  'dt': 1523689083,
#  'id': 2392505,
#  'main': {'grnd_level': 984.79,
#           'humidity': 91,
#           'pressure': 984.79,
#           'sea_level': 1023.79,
#           'temp': 23.86,
#           'temp_max': 23.86,
#           'temp_min': 23.86},
#  'name': 'Nikki',
#  'sys': {'country': 'BJ',
#          'message': 0.1632,
#          'sunrise': 1523684236,
#          'sunset': 1523728655},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 206.505, 'speed': 6.11}}
# city generated: punta arenas,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813E0E940>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1523685600,
#  'id': 3874787,
#  'main': {'humidity': 87,
#           'pressure': 1001,
#           'temp': 6,
#           'temp_max': 6,
#           'temp_min': 6},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 4642,
#          'message': 0.0068,
#          'sunrise': 1523705412,
#          'sunset': 1523742991,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'speed': 1}}
# city generated: provideniya,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81522DD68>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1523689072,
#  'id': 4031574,
#  'main': {'grnd_level': 1018.02,
#           'humidity': 100,
#           'pressure': 1018.02,
#           'sea_level': 1024.56,
#           'temp': -5.8,
#           'temp_max': -5.8,
#           'temp_min': -5.8},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'message': 0.0041,
#          'sunrise': 1523721683,
#          'sunset': 1523776004},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 53.0051, 'speed': 12.56}}
# city generated: voyvozh,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8152DFE10>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: new norfolk,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B44A90>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.78, 'lon': 147.06},
#  'dt': 1523687400,
#  'id': 2155415,
#  'main': {'humidity': 41,
#           'pressure': 978,
#           'temp': 15,
#           'temp_max': 15,
#           'temp_min': 15},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0039,
#          'sunrise': 1523652155,
#          'sunset': 1523691655,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 9.8}}
# city generated: khatanga,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8151485F8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1523689072,
#  'id': 2022572,
#  'main': {'grnd_level': 1007.89,
#           'humidity': 95,
#           'pressure': 1007.89,
#           'sea_level': 1012.56,
#           'temp': -7.8,
#           'temp_max': -7.8,
#           'temp_min': -7.8},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU',
#          'message': 0.0042,
#          'sunrise': 1523652942,
#          'sunset': 1523712533},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 238.505, 'speed': 6.09}}
# city generated: belushya guba,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150BBEB8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: sao filipe,cv
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813F47E80>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: rikitea,pf
# city generated: vostok,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8152DFB70>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 46.45, 'lon': 135.83},
#  'dt': 1523689073,
#  'id': 2013279,
#  'main': {'grnd_level': 958.69,
#           'humidity': 100,
#           'pressure': 958.69,
#           'sea_level': 1025.57,
#           'temp': 3.41,
#           'temp_max': 3.41,
#           'temp_min': 3.41},
#  'name': 'Vostok',
#  'rain': {'3h': 0.86382},
#  'sys': {'country': 'RU',
#          'message': 0.0037,
#          'sunrise': 1523650328,
#          'sunset': 1523698963},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 151.005, 'speed': 1.24}}
# city generated: port lincoln,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B494A8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -34.72, 'lon': 135.86},
#  'dt': 1523689074,
#  'id': 2063036,
#  'main': {'grnd_level': 1019.48,
#           'humidity': 87,
#           'pressure': 1019.48,
#           'sea_level': 1023.1,
#           'temp': 18.06,
#           'temp_max': 18.06,
#           'temp_min': 18.06},
#  'name': 'Port Lincoln',
#  'sys': {'country': 'AU',
#          'message': 0.0057,
#          'sunrise': 1523654343,
#          'sunset': 1523694850},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 243.505, 'speed': 11.29}}
# duplicate city: hobart,au
# city generated: busselton,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B35C50>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1523689074,
#  'id': 2075265,
#  'main': {'grnd_level': 1035.37,
#           'humidity': 97,
#           'pressure': 1035.37,
#           'sea_level': 1036.39,
#           'temp': 20.71,
#           'temp_max': 20.71,
#           'temp_min': 20.71},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'message': 0.0032,
#          'sunrise': 1523659209,
#          'sunset': 1523699829},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 196.005, 'speed': 3.59}}
# city generated: porto santo,pt
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814E9DE80>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: khatanga,ru
# duplicate city: vaini,to
# city generated: ilulissat,gl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81427A080>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: carnarvon,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B380B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -30.97, 'lon': 22.13},
#  'dt': 1523689075,
#  'id': 1014034,
#  'main': {'grnd_level': 881.12,
#           'humidity': 95,
#           'pressure': 881.12,
#           'sea_level': 1036.27,
#           'temp': 12.41,
#           'temp_max': 12.41,
#           'temp_min': 12.41},
#  'name': 'Carnarvon',
#  'rain': {'3h': 0.12043},
#  'sys': {'country': 'ZA',
#          'message': 0.0035,
#          'sunrise': 1523681449,
#          'sunset': 1523722329},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 40.0051, 'speed': 2.11}}
# city generated: kodiak,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8154B12B0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1523688780,
#  'id': 4407665,
#  'main': {'humidity': 87,
#           'pressure': 999,
#           'temp': 9,
#           'temp_max': 9,
#           'temp_min': 9},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 1664,
#          'message': 0.0045,
#          'sunrise': 1523706135,
#          'sunset': 1523753808,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 3.1}}
# city generated: sumenep,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814469390>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: georgetown,sh
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81532CBA8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1523685600,
#  'id': 3378644,
#  'main': {'humidity': 94,
#           'pressure': 1013,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'id': 4343,
#          'message': 0.0043,
#          'sunrise': 1523699091,
#          'sunset': 1523743250,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.1}}
# duplicate city: khatanga,ru
# city generated: ostrovnoy,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815202710>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 68.05, 'lon': 39.51},
#  'dt': 1523689076,
#  'id': 556268,
#  'main': {'grnd_level': 1000.68,
#           'humidity': 92,
#           'pressure': 1000.68,
#           'sea_level': 1026.83,
#           'temp': 1.06,
#           'temp_max': 1.06,
#           'temp_min': 1.06},
#  'name': 'Ostrovnoy',
#  'sys': {'country': 'RU',
#          'message': 0.0932,
#          'sunrise': 1523669688,
#          'sunset': 1523725936},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 281.505, 'speed': 7.44}}
# duplicate city: khatanga,ru
# duplicate city: hilo,us
# city generated: grindavik,is
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814674518>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: jamestown,sh
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81532CC50>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1523689077,
#  'id': 2069194,
#  'main': {'grnd_level': 964.69,
#           'humidity': 84,
#           'pressure': 964.69,
#           'sea_level': 1022.53,
#           'temp': 15.96,
#           'temp_max': 15.96,
#           'temp_min': 15.96},
#  'name': 'Jamestown',
#  'rain': {'3h': 1.17874},
#  'sys': {'country': 'AU',
#          'message': 0.0869,
#          'sunrise': 1523653602,
#          'sunset': 1523694278},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 251.005, 'speed': 9.36}}
# city generated: santa isabel do rio negro,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813CFF1D0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -0.41, 'lon': -65.02},
#  'dt': 1523689078,
#  'id': 3662489,
#  'main': {'grnd_level': 1018.35,
#           'humidity': 95,
#           'pressure': 1018.35,
#           'sea_level': 1024.19,
#           'temp': 24.61,
#           'temp_max': 24.61,
#           'temp_min': 24.61},
#  'name': 'Santa Isabel do Rio Negro',
#  'sys': {'country': 'BR',
#          'message': 0.3894,
#          'sunrise': 1523701032,
#          'sunset': 1523744597},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102.505, 'speed': 0.91}}
# city generated: ust-nera,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8152C20B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 64.57, 'lon': 143.24},
#  'dt': 1523689078,
#  'id': 2120048,
#  'main': {'grnd_level': 900.08,
#           'humidity': 73,
#           'pressure': 900.08,
#           'sea_level': 1026.95,
#           'temp': -5.95,
#           'temp_max': -5.95,
#           'temp_min': -5.95},
#  'name': 'Ust-Nera',
#  'sys': {'country': 'RU',
#          'message': 0.0048,
#          'sunrise': 1523645882,
#          'sunset': 1523699925},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310.505, 'speed': 1.36}}
# duplicate city: carnarvon,au
# city generated: ouro preto,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813CCB0B8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -20.39, 'lon': -43.5},
#  'dt': 1523689078,
#  'id': 3455671,
#  'main': {'grnd_level': 950.58,
#           'humidity': 94,
#           'pressure': 950.58,
#           'sea_level': 1031.25,
#           'temp': 17.96,
#           'temp_max': 17.96,
#           'temp_min': 17.96},
#  'name': 'Ouro Preto',
#  'sys': {'country': 'BR',
#          'message': 0.0051,
#          'sunrise': 1523696698,
#          'sunset': 1523738587},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 78.5051, 'speed': 0.94}}
# city generated: naze,jp
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814766278>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 5.43, 'lon': 7.07},
#  'dt': 1523689079,
#  'id': 2337542,
#  'main': {'grnd_level': 1006.19,
#           'humidity': 91,
#           'pressure': 1006.19,
#           'sea_level': 1025.73,
#           'temp': 23.91,
#           'temp_max': 23.91,
#           'temp_min': 23.91},
#  'name': 'Naze',
#  'sys': {'country': 'NG',
#          'message': 0.0052,
#          'sunrise': 1523683497,
#          'sunset': 1523727539},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219.005, 'speed': 3.04}}
# city generated: cabo san lucas,mx
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8149C7FD0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1523684460,
#  'id': 3985710,
#  'main': {'humidity': 68,
#           'pressure': 1015,
#           'temp': 20,
#           'temp_max': 20,
#           'temp_min': 20},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 4015,
#          'message': 0.0612,
#          'sunrise': 1523710785,
#          'sunset': 1523756407,
#          'type': 1},
#  'visibility': 12874,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 5.1}}
# city generated: boshnyakovo,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150D4AC8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 49.65, 'lon': 142.17},
#  'dt': 1523689079,
#  'id': 2126493,
#  'main': {'grnd_level': 998.09,
#           'humidity': 67,
#           'pressure': 998.09,
#           'sea_level': 1028.45,
#           'temp': 1.31,
#           'temp_max': 1.31,
#           'temp_min': 1.31},
#  'name': 'Boshnyakovo',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1523648500,
#          'sunset': 1523697756},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 316.505, 'speed': 2.26}}
# city generated: lompoc,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8154DDBA8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 34.64, 'lon': -120.46},
#  'dt': 1523687700,
#  'id': 5367788,
#  'main': {'humidity': 57,
#           'pressure': 1025,
#           'temp': 13.05,
#           'temp_max': 16,
#           'temp_min': 10},
#  'name': 'Lompoc',
#  'sys': {'country': 'US',
#          'id': 492,
#          'message': 0.0097,
#          'sunrise': 1523712660,
#          'sunset': 1523759609,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 6.00513, 'speed': 3.81}}
# city generated: mar del plata,ar
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B079E8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1523689083,
#  'id': 3863379,
#  'main': {'grnd_level': 1003.52,
#           'humidity': 53,
#           'pressure': 1003.52,
#           'sea_level': 1024.88,
#           'temp': 12.81,
#           'temp_max': 12.81,
#           'temp_min': 12.81},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.0034,
#          'sunrise': 1523703972,
#          'sunset': 1523742814},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 288.505, 'speed': 5.29}}
# duplicate city: new norfolk,au
# city generated: lebu,cl
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813E0B550>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1523689083,
#  'id': 344979,
#  'main': {'grnd_level': 778.74,
#           'humidity': 85,
#           'pressure': 778.74,
#           'sea_level': 1024.92,
#           'temp': 15.91,
#           'temp_max': 15.91,
#           'temp_min': 15.91},
#  'name': 'Lebu',
#  'sys': {'country': 'ET',
#          'message': 0.0035,
#          'sunrise': 1523675756,
#          'sunset': 1523720089},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102.005, 'speed': 1.71}}
# city generated: kavieng,pg
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814BC9B70>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: tilichiki,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81529F048>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: maloshuyka,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8151AA390>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: mys shmidta,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8151C8A20>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: bengkulu,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814436A20>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: hilo,us
# city generated: tomari,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81529FF28>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 47.76, 'lon': 142.06},
#  'dt': 1523689088,
#  'id': 2120530,
#  'main': {'grnd_level': 1019.72,
#           'humidity': 66,
#           'pressure': 1019.72,
#           'sea_level': 1028.81,
#           'temp': 4.06,
#           'temp_max': 4.06,
#           'temp_min': 4.06},
#  'name': 'Tomari',
#  'sys': {'country': 'RU',
#          'message': 0.0042,
#          'sunrise': 1523648713,
#          'sunset': 1523697591},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 286.005, 'speed': 1.44}}
# duplicate city: castro,cl
# city generated: katobu,id
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81444A748>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -4.94, 'lon': 122.53},
#  'dt': 1523689088,
#  'id': 1640972,
#  'main': {'grnd_level': 1015.59,
#           'humidity': 75,
#           'pressure': 1015.59,
#           'sea_level': 1019.01,
#           'temp': 31.61,
#           'temp_max': 31.61,
#           'temp_min': 31.61},
#  'name': 'Katobu',
#  'sys': {'country': 'ID',
#          'message': 0.0043,
#          'sunrise': 1523656207,
#          'sunset': 1523699409},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 78.5051, 'speed': 1.84}}
# city generated: guarapari,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813C75630>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: dikson,ru
# duplicate city: new norfolk,au
# city generated: luderitz,na
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814AC2160>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: east london,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8158A2B70>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: thompson,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813DAE908>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1523685600,
#  'id': 6165406,
#  'main': {'humidity': 61,
#           'pressure': 1034,
#           'temp': -11,
#           'temp_max': -11,
#           'temp_min': -11},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 3406,
#          'message': 0.0033,
#          'sunrise': 1523705280,
#          'sunset': 1523756189,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'speed': 1}}
# city generated: te anau,nz
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814B6EF98>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -45.41, 'lon': 167.72},
#  'dt': 1523689089,
#  'id': 2181625,
#  'main': {'grnd_level': 959.58,
#           'humidity': 78,
#           'pressure': 959.58,
#           'sea_level': 1024.52,
#           'temp': 6.46,
#           'temp_max': 6.46,
#           'temp_min': 6.46},
#  'name': 'Te Anau',
#  'sys': {'country': 'NZ',
#          'message': 0.0034,
#          'sunrise': 1523647384,
#          'sunset': 1523686507},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 13.0051, 'speed': 0.79}}
# city generated: nouadhibou,mr
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81498BC18>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: port alfred,za
# duplicate city: kodiak,us
# duplicate city: punta arenas,cl
# city generated: flinders,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B3B390>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.58, 'lon': 150.85},
#  'dt': 1523687400,
#  'id': 6255012,
#  'main': {'humidity': 19,
#           'pressure': 997,
#           'temp': 27,
#           'temp_max': 27,
#           'temp_min': 27},
#  'name': 'Flinders',
#  'sys': {'country': 'AU',
#          'id': 8231,
#          'message': 0.0083,
#          'sunrise': 1523650736,
#          'sunset': 1523691264,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310, 'gust': 15.9, 'speed': 8.7}}
# duplicate city: rikitea,pf
# city generated: isla mujeres,mx
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814A095F8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: port blair,in
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8145DFF60>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: uruguaiana,br
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813D30CF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -29.77, 'lon': -57.08},
#  'dt': 1523685600,
#  'id': 3445679,
#  'main': {'humidity': 88,
#           'pressure': 1022,
#           'temp': 18,
#           'temp_max': 18,
#           'temp_min': 18},
#  'name': 'Uruguaiana',
#  'sys': {'country': 'BR',
#          'id': 4725,
#          'message': 0.0032,
#          'sunrise': 1523700406,
#          'sunset': 1523741388,
#          'type': 1},
#  'visibility': 4000,
#  'weather': [{'description': 'thunderstorm with rain',
#               'icon': '11n',
#               'id': 201,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 140, 'speed': 7.2}}
# city generated: dudinka,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150FA6A0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 69.41, 'lon': 86.18},
#  'dt': 1523689091,
#  'id': 1507116,
#  'main': {'grnd_level': 1001.17,
#           'humidity': 95,
#           'pressure': 1001.17,
#           'sea_level': 1008.79,
#           'temp': -9.3,
#           'temp_max': -9.3,
#           'temp_min': -9.3},
#  'name': 'Dudinka',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1523658020,
#          'sunset': 1523715224},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 202.005, 'speed': 4.06}}
# city generated: yellowknife,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813DBB668>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1523685600,
#  'id': 6185377,
#  'main': {'humidity': 58,
#           'pressure': 1010,
#           'temp': -1,
#           'temp_max': -1,
#           'temp_min': -1},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 3558,
#          'message': 0.0083,
#          'sunrise': 1523708058,
#          'sunset': 1523761372,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 4.6}}
# city generated: ayan,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150AC6A0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.67, 'lon': 33.6},
#  'dt': 1523689092,
#  'id': 749747,
#  'main': {'grnd_level': 885.49,
#           'humidity': 59,
#           'pressure': 885.49,
#           'sea_level': 1032.66,
#           'temp': 12.76,
#           'temp_max': 12.76,
#           'temp_min': 12.76},
#  'name': 'Ayan',
#  'sys': {'country': 'TR',
#          'message': 0.1304,
#          'sunrise': 1523675307,
#          'sunset': 1523723034},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 25.5051, 'speed': 1.44}}
# city generated: le port,re
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814ECE160>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 42.87, 'lon': 1.37},
#  'dt': 1523689093,
#  'id': 3036965,
#  'main': {'grnd_level': 837.67,
#           'humidity': 100,
#           'pressure': 837.67,
#           'sea_level': 1029.71,
#           'temp': 1.11,
#           'temp_max': 1.11,
#           'temp_min': 1.11},
#  'name': 'Le Port',
#  'rain': {'3h': 0.57727},
#  'sys': {'country': 'FR',
#          'message': 0.0422,
#          'sunrise': 1523682864,
#          'sunset': 1523730950},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 75.0051, 'speed': 0.16}}
# city generated: cape town,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81589FF60>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1523685600,
#  'id': 3369157,
#  'main': {'humidity': 82,
#           'pressure': 1021,
#           'temp': 16,
#           'temp_max': 16,
#           'temp_min': 16},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 6529,
#          'message': 0.0094,
#          'sunrise': 1523682500,
#          'sunset': 1523723056,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 6.2}}
# city generated: hay river,ca
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813D753C8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 60.82, 'lon': -115.79},
#  'dt': 1523685600,
#  'id': 5972762,
#  'main': {'humidity': 64,
#           'pressure': 1008,
#           'temp': 3,
#           'temp_max': 3,
#           'temp_min': 3},
#  'name': 'Hay River',
#  'sys': {'country': 'CA',
#          'id': 3530,
#          'message': 0.1953,
#          'sunrise': 1523708731,
#          'sunset': 1523761366,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 2.6}}
# duplicate city: thompson,ca
# city generated: westerville,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81482B2B0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 40.13, 'lon': -82.93},
#  'dt': 1523686620,
#  'id': 5176472,
#  'main': {'humidity': 55,
#           'pressure': 1010,
#           'temp': 16.89,
#           'temp_max': 19,
#           'temp_min': 13},
#  'name': 'Westerville',
#  'sys': {'country': 'US',
#          'id': 2176,
#          'message': 0.005,
#          'sunrise': 1523703285,
#          'sunset': 1523750981,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 3.1}}
# city generated: port elizabeth,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8158AF6A0>
# ...
#          'sunset': 1523717099},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 265.005, 'speed': 3.49}}
# duplicate city: fortuna,us
# duplicate city: vaini,to
# duplicate city: kavieng,pg
# duplicate city: tuktoyaktuk,ca
# duplicate city: jamestown,sh
# duplicate city: severo-kurilsk,ru
# city generated: amarpur,in
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8144A0470>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 23.52, 'lon': 91.65},
#  'dt': 1523689200,
#  'id': 1278897,
#  'main': {'humidity': 46,
#           'pressure': 1007,
#           'temp': 34,
#           'temp_max': 34,
#           'temp_min': 34},
#  'name': 'Amarpur',
#  'sys': {'country': 'IN',
#          'id': 7781,
#          'message': 0.0035,
#          'sunrise': 1523662409,
#          'sunset': 1523708051,
#          'type': 1},
#  'visibility': 6000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 1.5}}
# duplicate city: kapaa,us
# duplicate city: taolanaro,mg
# city generated: igrim,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81511CCF8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 63.19, 'lon': 64.42},
#  'dt': 1523689590,
#  'id': 1505965,
#  'main': {'grnd_level': 1016.32,
#           'humidity': 68,
#           'pressure': 1016.32,
#           'sea_level': 1020.5,
#           'temp': -1.45,
#           'temp_max': -1.45,
#           'temp_min': -1.45},
#  'name': 'Igrim',
#  'sys': {'country': 'RU',
#          'message': 0.0029,
#          'sunrise': 1523665080,
#          'sunset': 1523718545},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 259.005, 'speed': 5.16}}
# duplicate city: ushuaia,ar
# duplicate city: bambous virieux,mu
# duplicate city: barrow,us
# duplicate city: jamestown,sh
# duplicate city: rock sound,bs
# city generated: chabahar,ir
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81465BEF0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 25.29, 'lon': 60.65},
#  'dt': 1523689591,
#  'id': 1161724,
#  'main': {'grnd_level': 1022.64,
#           'humidity': 86,
#           'pressure': 1022.64,
#           'sea_level': 1023.67,
#           'temp': 28.81,
#           'temp_max': 28.81,
#           'temp_min': 28.81},
#  'name': 'Chabahar',
#  'sys': {'country': 'IR',
#          'message': 0.0035,
#          'sunrise': 1523669756,
#          'sunset': 1523715583},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 277.505, 'speed': 2.46}}
# duplicate city: saskylakh,ru
# duplicate city: rikitea,pf
# city generated: plavsk,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815218A90>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 53.71, 'lon': 37.29},
#  'dt': 1523689591,
#  'id': 509052,
#  'main': {'grnd_level': 1019.64,
#           'humidity': 92,
#           'pressure': 1019.64,
#           'sea_level': 1046.69,
#           'temp': 3.66,
#           'temp_max': 3.66,
#           'temp_min': 3.66},
#  'name': 'Plavsk',
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1523673170,
#          'sunset': 1523723431},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 62.5051, 'speed': 2.04}}
# duplicate city: hermanus,za
# duplicate city: ribeira grande,pt
# duplicate city: cortez,us
# duplicate city: ngukurr,au
# duplicate city: sao filipe,cv
# city generated: najran,sa
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815314278>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 17.54, 'lon': 44.22},
#  'dt': 1523685600,
#  'id': 103630,
#  'main': {'humidity': 47,
#           'pressure': 1019,
#           'temp': 25,
#           'temp_max': 25,
#           'temp_min': 25},
#  'name': 'Najran',
#  'sys': {'country': 'SA',
#          'id': 6998,
#          'message': 0.0038,
#          'sunrise': 1523674068,
#          'sunset': 1523719149,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 1}}
# duplicate city: kodiak,us
# duplicate city: albany,au
# duplicate city: vaini,to
# city generated: milingimbi,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B41C18>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: kruisfontein,za
# duplicate city: barrow,us
# duplicate city: katsuura,jp
# city generated: aloleng,ph
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814BD9EB8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: busselton,au
# duplicate city: katobu,id
# duplicate city: illoqqortoormiut,gl
# duplicate city: vaini,to
# duplicate city: bargal,so
# duplicate city: chumikan,ru
# duplicate city: esperance,au
# duplicate city: grand centre,ca
# duplicate city: bluff,nz
# duplicate city: cidreira,br
# duplicate city: taolanaro,mg
# duplicate city: kaka,tm
# duplicate city: port elizabeth,za
# duplicate city: bengkulu,id
# duplicate city: barrow,us
# duplicate city: avarua,ck
# duplicate city: cape town,za
# duplicate city: saint george,bm
# duplicate city: vaitupu,wf
# duplicate city: georgetown,sh
# duplicate city: hobart,au
# duplicate city: port alfred,za
# duplicate city: punta arenas,cl
# duplicate city: ribeira grande,pt
# duplicate city: thompson,ca
# city generated: robat karim,ir
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81466AE10>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 35.49, 'lon': 51.08},
#  'dt': 1523687400,
#  'id': 118367,
#  'main': {'humidity': 41,
#           'pressure': 1013,
#           'temp': 15.58,
#           'temp_max': 18,
#           'temp_min': 13},
#  'name': 'Robat Karim',
#  'sys': {'country': 'IR',
#          'id': 7032,
#          'message': 0.0044,
#          'sunrise': 1523671473,
#          'sunset': 1523718472,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 6.2}}
# duplicate city: nanakuli,us
# duplicate city: port alfred,za
# duplicate city: khatanga,ru
# city generated: murray bridge,au
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813B44438>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -35.12, 'lon': 139.28},
#  'dt': 1523689593,
#  'id': 2065176,
#  'main': {'grnd_level': 1013.81,
#           'humidity': 88,
#           'pressure': 1013.81,
#           'sea_level': 1018.72,
#           'temp': 17.11,
#           'temp_max': 17.11,
#           'temp_min': 17.11},
#  'name': 'Murray Bridge',
#  'sys': {'country': 'AU',
#          'message': 0.0033,
#          'sunrise': 1523653545,
#          'sunset': 1523694007},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 247.505, 'speed': 12.91}}
# duplicate city: kaitangata,nz
# city generated: tricase,it
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814713390>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 39.93, 'lon': 18.36},
#  'dt': 1523685300,
#  'id': 2522857,
#  'main': {'humidity': 77,
#           'pressure': 1016,
#           'temp': 12.83,
#           'temp_max': 15,
#           'temp_min': 11},
#  'name': 'Tricase',
#  'sys': {'country': 'IT',
#          'id': 5756,
#          'message': 0.0032,
#          'sunrise': 1523679015,
#          'sunset': 1523726639,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30, 'speed': 7.7}}
# duplicate city: quang ngai,vn
# duplicate city: pangnirtung,ca
# duplicate city: victoria,sc
# duplicate city: jamestown,sh
# duplicate city: butaritari,ki
# duplicate city: meyungs,pw
# duplicate city: rikitea,pf
# city generated: trussville,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8154AE780>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 33.62, 'lon': -86.61},
#  'dt': 1523687700,
#  'id': 4094212,
#  'main': {'humidity': 82,
#           'pressure': 1016,
#           'temp': 19.3,
#           'temp_max': 21,
#           'temp_min': 17},
#  'name': 'Trussville',
#  'sys': {'country': 'US',
#          'id': 240,
#          'message': 0.0037,
#          'sunrise': 1523704606,
#          'sunset': 1523751416,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 181.505, 'speed': 3.99}}
# duplicate city: qaanaaq,gl
# duplicate city: jamestown,sh
# duplicate city: cape town,za
# duplicate city: buala,sb
# duplicate city: mataura,pf
# duplicate city: hithadhoo,mv
# city generated: gulshat,kz
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8149054E0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: khatanga,ru
# duplicate city: albany,au
# duplicate city: atuona,pf
# duplicate city: ribeira grande,pt
# city generated: xinan,cn
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A813E7C7F0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 22.55, 'lon': 113.89},
#  'dt': 1523687400,
#  'id': 1795565,
#  'main': {'humidity': 69,
#           'pressure': 1010,
#           'temp': 27.66,
#           'temp_max': 28,
#           'temp_min': 27},
#  'name': 'Xinan',
#  'sys': {'country': 'CN',
#          'id': 7888,
#          'message': 0.0058,
#          'sunrise': 1523657122,
#          'sunset': 1523702664,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 5.1}}
# duplicate city: nikolskoye,ru
# duplicate city: chokurdakh,ru
# duplicate city: airai,pw
# duplicate city: lixourion,gr
# duplicate city: belushya guba,ru
# duplicate city: port elizabeth,za
# duplicate city: ushuaia,ar
# duplicate city: yirol,sd
# duplicate city: ponta do sol,cv
# duplicate city: albany,au
# duplicate city: tilichiki,ru
# duplicate city: mataura,pf
# city generated: petropavlovsk-kamchatskiy,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815211F28>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: butaritari,ki
# duplicate city: puerto ayora,ec
# city generated: ewa beach,us
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A81554E8D0>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 21.32, 'lon': -158.01},
#  'dt': 1523687820,
#  'id': 5855051,
#  'main': {'humidity': 88,
#           'pressure': 1018,
#           'temp': 22.26,
#           'temp_max': 23,
#           'temp_min': 21},
#  'name': 'Ewa Beach',
#  'sys': {'country': 'US',
#          'id': 828,
#          'message': 0.0336,
#          'sunrise': 1523722399,
#          'sunset': 1523767875,
#          'type': 1},
#  'visibility': 3219,
#  'weather': [{'description': 'thunderstorm with rain',
#               'icon': '11n',
#               'id': 201,
#               'main': 'Thunderstorm'},
#              {'description': 'light intensity drizzle',
#               'icon': '09n',
#               'id': 300,
#               'main': 'Drizzle'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 70, 'speed': 5.7}}
# duplicate city: hasaki,jp
# city generated: clacton-on-sea,gb
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8141FD9B0>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: bredasdorp,za
# duplicate city: salalah,om
# duplicate city: porto novo,cv
# duplicate city: nikolskoye,ru
# duplicate city: bredasdorp,za
# duplicate city: faanui,pf
# duplicate city: bredasdorp,za
# city generated: berdigestyakh,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8150C0470>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 62.1, 'lon': 126.7},
#  'dt': 1523689595,
#  'id': 2026861,
#  'main': {'grnd_level': 996.06,
#           'humidity': 53,
#           'pressure': 996.06,
#           'sea_level': 1028,
#           'temp': 6.31,
#           'temp_max': 6.31,
#           'temp_min': 6.31},
#  'name': 'Berdigestyakh',
#  'sys': {'country': 'RU',
#          'message': 0.003,
#          'sunrise': 1523650402,
#          'sunset': 1523703326},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 254.005, 'speed': 3.14}}
# duplicate city: yellowknife,ca
# city generated: sovetskaya gavan,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A815275978>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: seryshevo,ru
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8152542E8>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: hamilton,bm
# duplicate city: arraial do cabo,br
# duplicate city: east london,za
# duplicate city: hermanus,za
# city generated: loten,no
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814B3BC50>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: bredasdorp,za
# duplicate city: bredasdorp,za
# city generated: mahajanga,mg
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A814963D68>
# associated weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city generated: cullinan,za
# processing request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x000001A8158A24A8>
# associated weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -25.67, 'lon': 28.53},
#  'dt': 1523688120,
#  'id': 1012413,
#  'main': {'humidity': 82,
#           'pressure': 1028,
#           'temp': 16.73,
#           'temp_max': 18,
#           'temp_min': 15},
#  'name': 'Cullinan',
#  'sys': {'country': 'ZA',
#          'id': 6569,
#          'message': 0.0039,
#          'sunrise': 1523679649,
#          'sunset': 1523721063,
#          'type': 1},
#  'visibility': 6000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 128.505, 'speed': 1.56}}

# %% [markdown]
# ## Merge data into Pandas DataFrame
#
# first we'll parse out the weather records into lists and then add them into a pandas dataframe

# %%
import pandas as pd
import numpy as np
lat = list()
long = list()
city_name = list()
country = list()
loc_id = list()
humidity = list()
temp = list()
pressure = list()
temp_max = list()
temp_min = list()
weather_description = list()
wind_speed = list()
visibility = list()
try:
    for rec in weather:
        lat.append(rec["coord"]['lat'])
        long.append(rec["coord"]['lon'])
        city_name.append(rec['name'])
        country.append(rec['sys']['country'])
        loc_id.append(rec['id'])
        humidity.append(rec['main']['humidity'])
        temp.append(rec['main']['temp'])
        pressure.append(rec['main']['pressure'])
        temp_max.append(rec['main']['temp_max'])
        temp_min.append(rec['main']['temp_min'])
        try:
            visibility.append(rec['visibility'])
        except:
            visibility.append(np.nan)
        weather_description.append(rec['weather'][0]['description'])
        wind_speed.append(rec['wind']['speed'])

    df = pd.DataFrame({
            'lat':lat,
            'long':long, 
            'city_name':city_name,
            'country':country,
            'loc_id':loc_id,
            'humidity':humidity,
            'temp':temp,
            'pressure':pressure,
            "temp_max":temp_max, 
            "temp_min":temp_min, 
            "visibility":visibility, 
            "weather_description":weather_description, 
            "wind_speed":wind_speed 

    })

    df.to_csv('weather_data.csv')
    pd.Series(duplicate_cities).to_csv('duplicates.csv')
    pd.Series(list(weatherless_cities)).to_csv('weatherless.csv')

except:
    df = pd.read_csv('weather_data.csv', index_col="Unnamed: 0")

# %%
df.head()
# Out:
#     city_name country  humidity    lat   loc_id    long  pressure   temp  \
# 0    Thompson      CA        71  55.74  6165406  -97.86   1025.00 -14.00
# 1      Castro      CL        96 -42.48  3896218  -73.76   1012.16  10.48
# 2      Kodiak      US        61  39.95  4407665  -94.76   1021.00   0.00
# 3   Busselton      AU        80 -33.64  2075265  115.35   1025.69  24.98
# 4  Niamtougou      TG        73   9.77  2364812    1.11    980.14  23.48
#
#    temp_max  temp_min  visibility weather_description  wind_speed
# 0    -14.00    -14.00     24140.0    scattered clouds        1.00
# 1     10.48     10.48         NaN           clear sky        1.51
# 2      0.00      0.00     16093.0     overcast clouds        8.20
# 3     24.98     24.98         NaN    scattered clouds        4.66
# 4     23.48     23.48         NaN           clear sky        2.86

# %%
# Create a column of temps that are in F
def Fahrenheit(temp):
    return temp * 9/5 + 32

df["temp_f"] = [Fahrenheit(x) for x in df['temp']]

# %%
df.describe()
# Out:
#           humidity          lat        loc_id         long     pressure  \
# count  1001.000000  1001.000000  1.001000e+03  1001.000000  1001.000000
# mean     74.647353    22.186424  2.700654e+06    14.323107   987.067522
# std      22.207173    29.496041  1.723607e+06    84.992669    58.618708
# min      11.000000   -54.810000  5.365400e+04  -173.230000   561.870000
# 25%      59.000000    -0.950000  1.497406e+06   -67.920000   987.000000
# 50%      81.000000    28.040000  2.255564e+06    19.530000  1008.000000
# 75%      93.000000    45.600000  3.832899e+06    82.340000  1017.510000
# max     100.000000    78.220000  8.010472e+06   177.510000  1044.340000
#
#               temp     temp_max     temp_min    visibility   wind_speed  \
# count  1001.000000  1001.000000  1001.000000    434.000000  1001.000000
# mean     10.638432    10.921389    10.331978  11523.728111     3.191868
# std      14.537628    14.441721    14.683692   5339.780878     2.311647
# min     -31.000000   -31.000000   -31.000000    200.000000     0.110000
# 25%       0.440000     1.000000     0.000000  10000.000000     1.500000
# 50%      12.800000    13.000000    12.580000  10000.000000     2.560000
# 75%      22.900000    23.000000    22.900000  16093.000000     4.260000
# max      40.000000    40.000000    40.000000  48279.000000    13.400000
#
#             temp_f
# count  1001.000000
# mean     51.149177
# std      26.167731
# min     -23.800000
# 25%      32.792000
# 50%      55.040000
# 75%      73.220000
# max     104.000000

# %% [markdown]
# ## Temperature (F) vs. Latitude
#
# * plotting temperature against latitude we can see how temperature varies across the earth's north south axis. We can make out that it's late winter in the northern hemisphere due to it being tilted upwards a bit

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
rcParams['axes.titlepad'] = 10 
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 50}

plt.rc('font', **font)
sns.jointplot(x=df['temp_f'].rename("Temperature (F)"), y=df['lat'].rename("Latitude"), kind='scatter',
              color='#69bcbb',size=10, stat_func=None)
#plt.title('Temperature and Latitude')
#g.fig.suptitle('Temperature and Latitude', fontsize=16)
plt.show()

# %% [markdown]
# ## Humidity (%) vs. Latitude

# %%
rcParams['axes.titlepad'] = 20
font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 70}

plt.rc('font', **font)
g = sns.JointGrid(x='humidity', y='lat', data=df, size=10, ratio=100)
g.plot_joint(plt.scatter,s=40, edgecolor='black')
plt.xlim(0,110)
plt.ylim(-90,90)
#plt.title('Humidity and Latitude')
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ## Cloudiness (%) vs. Latitude
#
# * in the more northerly regions of the world visibility goes up.

# %%
g = sns.JointGrid(x='visibility', y='lat', data=df, size=10, ratio=100)
g.plot_joint(plt.scatter, color='#3498DB',s=40, edgecolor='black')
#plt.title('Cloudiness and Latitude')
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Wind Speed (mph) vs. Latitude
#
# * Generally we can see that around the equator wind speeds are lower

# %%
g = sns.JointGrid(x='wind_speed', y='lat', data=df, size=10, ratio=100)
g.plot_joint(plt.scatter, color='#117A65',s=40, edgecolor='black')

#plt.title('Wind Speed and Latitude')
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Frequent duplicate cities
#
#
# * I used a random numbers generator to create lat, long values which were then fed into the citipy module. The citipy module will return the closest inhabited place of 500 and more, when given coordinates. If a city/town is more isolated, then it has a higher chance of being picked by the citipy module (given a uniform distribution of coordinates). Bellow is the top 10 locations most frequently returned locations by the citipy modules. Most of the towns are in nations from the southern hemisphere (Australia, New Zealand, South Africa, French Polynesia, Chile, Argentina) and coastal.

# %%
duplic = pd.Series(duplicate_cities).value_counts()[:10]
plt.rcParams["figure.figsize"] = (40,10)
plt.bar(duplic.index, duplic)
plt.xticks(rotation=70)
plt.title("Top Ten Most Randomly Found Cities")
plt.show()
#weatherless_cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-4c502a4ebbc2> in <module>()
# ----> 1 duplic = pd.Series(duplicate_cities).value_counts()[:10]
#       2 plt.rcParams["figure.figsize"] = (40,10)
#       3 plt.bar(duplic.index, duplic)
#       4 plt.xticks(rotation=70)
#       5 plt.title("Top Ten Most Randomly Found Cities")
#
# NameError: name 'duplicate_cities' is not defined

# %%
g = sns.JointGrid(x='pressure', y='lat', data=df, size=10, ratio=100)
g.plot_joint(plt.scatter, color='#34495E',s=40, edgecolor='black')

#plt.title('Pressure and Latitude')
plt.xlabel("Pressure")
plt.ylabel("Latitude")
plt.ylim(-90,90)
plt.show()

# %%
df.head(500).to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>city_name</th>\n      <th>country</th>\n      <th>humidity</th>\n      <th>lat</th>\n      <th>loc_id</th>\n      <th>long</th>\n      <th>pressure</th>\n      <th>temp</th>\n      <th>temp_max</th>\n      <th>temp_min</th>\n      <th>visibility</th>\n      <th>weather_description</th>\n      <th>wind_speed</th>\n      <th>temp_f</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Thompson</td>\n      <td>CA</td>\n      <td>71</td>\n      <td>55.74</td>\n      <td>6165406</td>\n      <td>-97.86</td>\n      <td>1025.00</td>\n      <td>-14.00</td>\n      <td>-14.00</td>\n      <td>-14.00</td>\n      <td>24140.0</td>\n      <td>scattered clouds</td>\n      <td>1.00</td>\n      <td>6.800</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Castro</td>\n      <td>CL</td>\n      <td>96</td>\n      <td>-42.48</td>\n      <td>3896218</td>\n      <td>-73.76</td>\n      <td>1012.16</td>\n      <td>10.48</td>\n      <td>10.48</td>\n      <td>10.48</td>\n      <td>NaN</td>\n      <td>clear sky</td>\n      <td>1.51</td>\n      <td>50.864</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Kodiak</td>\n      <td>US</td>\n      <td>61</td>\n      <td>39.95</td>\n      <td>4407665</td>\n      <td>-94.76</td>\n      <td>1021.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>16093.0</td>\n      <td>overcast clouds</td>\n      <td>8.20</td>\n      <td>32.000</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Busselton</td>\n      <td>AU</td>\n      <td>80</td>\n      <td>-33.64</td>\n      <td>2075265</td>\n      <td>115.35</td>\n      <td>1025.69</td>\n      <td>24.98</td>\n      <td>24.98</td>\n      <td>24.98</td>\n      <td>NaN</td>\n      <td>scattered clouds</td>\n      <td>4.66</td>\n      <td>76.964</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Niamtougou</td>\n      <td>TG</td>\n      <td>73</td>\n      <td>9.77</td>\n      <td>2364812</td>\n      <td>1.11</td>\n      <td>980.14</td>\n      <td>23.48</td>\n      <td>23.48</td>\n      <td>23.48</td>\n      <td>NaN</td>\n      <td>clear sky</td>\n      <td>2.86</td>\n      <td>74.264</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Hilo</td>\n      <td>US</td>\n      <td>88</td>\n      <td>19.71</td>\n      <td>5855927</td>\n      <td>-155.08</td>\n      <td>1016.00</td>\n      <td>15.63</td>\n      <td>20.00</td>\n      <td>12.00</td>\n      <td>11265.0</td>\n      <td>light rain</td>\n      <td>4.10</td>\n      <td>60.134</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Lompoc</td>\n      <td>US</td>\n      <td>57</td>\n      <td>34.64</td>\n      <td>5367788</td>\n      <td>-120.46</td>\n      <td>1018.00</td>\n      <td>10.86</td>\n      <td>12.00</td>\n      <td>9.00</td>\n      <td>16093.0</td>\n      <td>clear sky</td>\n      <td>1.50</td>\n      <td>51.548</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Punta Arenas</td>\n      <td>CL</td>\n      <td>81</td>\n      <td>-53.16</td>\n      <td>3874787</td>\n      <td>-70.91</td>\n      <td>990.00</td>\n      <td>12.00</td>\n      <td>12.00</td>\n      <td>12.00</td>\n      <td>10000.0</td>\n      <td>clear sky</td>\n      <td>8.70</td>\n      <td>53.600</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Ranau</td>\n      <td>MY</td>\n      <td>53</td>\n      <td>5.95</td>\n      <td>1733502</td>\n      <td>116.67</td>\n      <td>935.88</td>\n      <td>28.68</td>\n      <td>28.68</td>\n      <td>28.68</td>\n      <td>NaN</td>\n      <td>clear sky</td>\n      <td>0.51</td>\n      <td>83.624</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Hermanus</td>\n      <td>ZA</td>\n      <td>95</td>\n      <td>-34.42</td>\n      <td>3366880</td>\n      <td>19.24</td>\n      <td>987.68</td>\n      <td>17.20</td>\n      <td>17.20</td>\n      <td>17.20</td>\n      <td>NaN</td>\n      <td>light rain</td>\n      <td>1.76</td>\n      < ...
